# %%
import cmipld,glob,sys
from pyld import jsonld
from cmipld.utils.git.repo_info import cmip_info
from cmipld.utils.git.

def check(file):
    expanded = jsonld.expand(file)
    # assert (expanded)<2, "This check is not inten"
    
    results = {}
    
    for entry in expanded:

        values = entry.values()

        ids = set([item['@id'] for elem in values if isinstance(elem, list)
            for item in elem if isinstance(item, dict) and '@id' in item])

        broken = []

        for i in ids: 
            try:
                jsonld.expand(i)
            except Exception as ex:
                # print(f"Broken link: {i} ({ex})")
                broken.append(i)
            
        results[entry.get('@id')] = {'broken_links': broken, 'all_links': ids}
        
    return results


def compact(log):
    reverse = {}
    for k,v in log.items():
        for b in v['broken_links']:
            if b not in reverse:
                reverse[b] = []
            reverse[b].append(k)

    return cmipld.compact_direct_url(str(reverse))



def broken_links_summary(url):
    result = json.loads(compact(check(url)).replace("'", '"'))
    summary = ''
    for k,v in result.items():
        summary += f"#### Broken: {k}\n"
        for ref in v:
            summary += f" - Referenced by: {ref}\n"
        summary += '\n'
    return summary


def main(file):
    # file = 'cmip7:experiment/graph.json'
    
    prefix = cmip_info()['whoami']
    
    if sys.argv[1] == 'project':
        
        
        
        for file in glob.glob('project/*.json'):
            file = file.split('/')[-1]
            print(f"Checking {file}...")
            try:
                broken = broken_links_summary(f'cmip7:project/{file}')
            except Exception as ex:
                broken = f"#### Error checking file: {file}"
                
            if broken:
                print(broken)
                print('\n\n')
    
    
    else:
        file = f'{prefix}:{sys.argv[1]}/graph.json'
        print(f"Checking {file}...")
        broken = broken_links_summary(file)

        if broken:
            print(broken)
            
                
    
    
    log = check(file)
    print(log)

# %%
cmip_info()
# Out:
# make test for url2io
#                             ╭─────────────────── Repository Info ────────────────────╮
#                             │                  Parsing repo: cmip7                   │
#                             │    Location: https://github.com/WCRP-CMIP/CMIP7-CVs    │
#                             │ Github IO link: https://wcrp-cmip.github.io/CMIP7-CVs/ │
#                             ╰────────────────────────────────────────────────────────╯
# {'whoami': 'cmip7', 'path': '/Users/daniel.ellis/WIPwork/CMIP7-CVs', 'name': 'CMIP7-CVs', 'url': 'https://github.com/WCRP-CMIP/CMIP7-CVs', 'io': 'https://wcrp-cmip.github.io/CMIP7-CVs/'}

# %%
url = 'cmip7:experiment/graph.json'

# %%
project = ''

for file in glob.glob('../project/*.json'):
    file = file.split('/')[-1]
    print(f"Checking {file}...")
    try:
        broken = broken_links_summary(f'cmip7:project/{file}')
    except Exception as ex:
        broken = f"#### Error checking file: {file}"
    if broken:
        print(broken)
# Out:
# Checking mip_era.json...
# Checking frequency.json...
# Checking horizontal_label.json...
# Checking source_type.json...
# Checking drs.json...
# Checking realm.json...
# Checking tracking_id.json...
# Checking native_nominal_resolution.json...
# Checking repo.json...
# Checking vertical_label.json...
# Checking tables.json...
# Checking grid_label.json...
# ### Error checking file: grid_label.json
# Checking area_label.json...
# Checking archive_id.json...
# Checking license.json...
# Checking required_global_attributes.json...
# Checking product.json...
# Checking temporal_label.json...
# Checking index.json...
# Checking region.json...
# Checking activity.json...
