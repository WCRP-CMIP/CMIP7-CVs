# %% [markdown]
# # How to query JSON-LD files with RDF/SPARQL , and raw JSON.
# A notebook on reading in all the experiments and extracting all files with `-pending` in the name, and the relevant keys that still need to be filled in `pending`.

# %%
from cmipld import get, resolve_prefix
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.plugins.sparql import prepareQuery

# %% [markdown]
# ## Using RDFlib
# Another way to load this information is using the RDF library. This allows us to apply SPARQL queries on our JSONLD files.

# %%
# start by resolving the URL (we have not monkeypatched RDFLib to use cmipld prefixes yet)
url = resolve_prefix('cmip7:experiment/graph.json' )
# Out:
# Substituting prefix:
# cmip7: https://wcrp-cmip.github.io/CMIP7-CVs/experiment/graph.json

# %% [markdown]
# #### Load our experiments 'graph' file into the RDF graph.
# We can also load individual file this way, but a single grouped file is easier.

# %%
g = Graph()
g.parse(location = url, format="json-ld")  # or use data=json_string

# # To preview the JSON contents we can use:
# print(g.serialize(format='json-ld'))
# Out:
# <Graph identifier=Nc5e9a9bb8ed9467ca7c4cffa55800d69 (<class 'rdflib.graph.Graph'>)>

# %%
# --- SPARQL query ---
query = """

# Select subjects ending with "-pending" or predicates containing "pending"
# and return grouped, shortened predicates and objects

SELECT ?subject
       (GROUP_CONCAT(DISTINCT ?p_short; separator=", ") AS ?predicates)
       (GROUP_CONCAT(DISTINCT ?o_short; separator=", ") AS ?objects)
WHERE {
  # ?s ?p ?o .

  # Keep only subjects ending in '-pending' or predicates containing 'pending' (case-insensitive)
  FILTER (regex(str(?s), "-pending$") || regex(str(?p), "pending", "i"))

  # Shorten the subject for readability
  # Example: "https://wcrp-cmip.github.io/CMIP7-CVs/experiment/tipmip-pending"
  # becomes "tipmip-pending.json"
  BIND(CONCAT(STRAFTER(STR(?s), "experiment/"), ".json") AS ?subject)

  # Shorten predicate to just the last part after 'Experiment.'
  # Example: "...Experiment.model_realms" -> "model_realms"
  BIND(STRAFTER(STR(?p), "Experiment.") AS ?p_short)

  # Shorten object if it’s a CMIP7 experiment URI
  # Example: ".../experiment/tipmip" -> "tipmip"
  BIND(STRAFTER(STR(?o), "https://wcrp-cmip.github.io/CMIP7-CVs/experiment/") AS ?o_short)
}
GROUP BY ?subject
ORDER BY ?subject
"""

# %%
# --- Run query ---
results = g.query(query)

# --- Print grouped results ---
for row in results:
    print(f"Subject: {row.subject}")
    print(f"  Predicates: {row.predicates}")
    print(f"  Objects: {row.objects}")
    print()
# Out:
# Subject: amip-irr-pending.json
#   Predicates: activity, description, tier, parent_experiment, ui_label, , start_date, model_realms, validation_key, minimum_number_of_years
#   Objects: irrmip, , pending
#
# Subject: amip-noirr-pending.json
#   Predicates: model_realms, , start_date, minimum_number_of_years, description, activity, tier, parent_experiment, validation_key, ui_label
#   Objects: pending, , irrmip
#
# Subject: dcppa-assim-pending.json
#   Predicates: ui_label, , model_realms, minimum_number_of_years, start_date, description, tier, activity, parent_experiment, validation_key
#   Objects: , pending, dcpp
#
# Subject: dcppa-hindcast-pending.json
#   Predicates: validation_key, description, tier, activity, parent_experiment, ui_label, , model_realms, minimum_number_of_years, start_date
#   Objects: , dcpp, pending
#
# Subject: dcppb-forecast-pending.json
#   Predicates: description, tier, activity, parent_experiment, ui_label, , minimum_number_of_years, start_date, model_realms, validation_key
#   Objects: , dcpp, pending
#
# Subject: esm-s7h-nofirechange-pending.json
#   Predicates: description, parent_experiment, start_date, tier, ui_label, , activity, minimum_number_of_years, model_realms, validation_key
#   Objects: , pending, firemip
#
# Subject: esm-scen7-h-aer-pending.json
#   Predicates: ui_label, activity, validation_key, start_date, description, tier, , model_realms, minimum_number_of_years, parent_experiment
#   Objects: , fast-track, aerchemmip, pending
#
# Subject: esm-scen7-h-aq-pending.json
#   Predicates: start_date, model_realms, , minimum_number_of_years, parent_experiment, ui_label, description, activity, tier, validation_key
#   Objects: , pending, aerchemmip, fast-track
#
# Subject: esm-scen7-h-ext-pending.json
#   Predicates: model_realms, , parent_experiment, validation_key, start_date, minimum_number_of_years, ui_label, description, tier, activity
#   Objects: pending, , ismip7
#
# Subject: esm-scen7-h-pending.json
#   Predicates: , start_date, tier, model_realms, minimum_number_of_years, ui_label, validation_key, description, parent_experiment, activity
#   Objects: , pending, fast-track
#
# Subject: esm-scen7-hl-ext-pending.json
#   Predicates: minimum_number_of_years, model_realms, , start_date, description, tier, parent_experiment, ui_label, activity, validation_key
#   Objects: , pending, ismip7
#
# Subject: esm-scen7-hl-pending.json
#   Predicates: description, tier, , model_realms, minimum_number_of_years, ui_label, parent_experiment, activity, validation_key, start_date
#   Objects: , pending, fast-track
#
# Subject: esm-scen7-l-ext-pending.json
#   Predicates: tier, , model_realms, validation_key, parent_experiment, ui_label, minimum_number_of_years, start_date, description
#   Objects: , pending
#
# Subject: esm-scen7-l-pending.json
#   Predicates: validation_key, , minimum_number_of_years, ui_label, description, tier, activity, start_date, model_realms, parent_experiment
#   Objects: , fast-track, pending
#
# Subject: esm-scen7-ln-ext-pending.json
#   Predicates: tier, , model_realms, parent_experiment, validation_key, minimum_number_of_years, start_date, ui_label, description
#   Objects: , pending
#
# Subject: esm-scen7-ln-pending.json
#   Predicates: validation_key, model_realms, , parent_experiment, activity, start_date, description, tier, minimum_number_of_years, ui_label
#   Objects: , pending, fast-track
#
# Subject: esm-scen7-m-ext-pending.json
#   Predicates: tier, parent_experiment, activity, , start_date, minimum_number_of_years, model_realms, ui_label, description, validation_key
#   Objects: , pending, ismip7
#
# Subject: esm-scen7-m-pending.json
#   Predicates: start_date, description, tier, validation_key, , model_realms, parent_experiment, minimum_number_of_years, ui_label, activity
#   Objects: , pending, fast-track
#
# Subject: esm-scen7-ml-ext-pending.json
#   Predicates: description, tier, , activity, start_date, validation_key, model_realms, parent_experiment, ui_label, minimum_number_of_years
#   Objects: , ismip7, pending
#
# Subject: esm-scen7-ml-pending.json
#   Predicates: tier, validation_key, parent_experiment, minimum_number_of_years, ui_label, activity, , start_date, model_realms, description
#   Objects: , pending, fast-track
#
# Subject: esm-scen7-vl-aer-pending.json
#   Predicates: model_realms, ui_label, , validation_key, activity, description, tier, minimum_number_of_years, parent_experiment, start_date
#   Objects: pending, , aerchemmip, fast-track
#
# Subject: esm-scen7-vl-aq-pending.json
#   Predicates: , start_date, validation_key, model_realms, description, activity, tier, minimum_number_of_years, parent_experiment, ui_label
#   Objects: , pending, aerchemmip, fast-track
#
# Subject: esm-scen7-vl-ext-pending.json
#   Predicates: tier, parent_experiment, activity, , model_realms, minimum_number_of_years, start_date, ui_label, validation_key, description
#   Objects: , pending, ismip7
#
# Subject: esm-scen7-vl-pending.json
#   Predicates: minimum_number_of_years, ui_label, description, tier, parent_experiment, activity, , start_date, validation_key, model_realms
#   Objects: , pending, fast-track
#
# Subject: highres-future-scen7-m-pending.json
#   Predicates: , parent_experiment, activity, ui_label, minimum_number_of_years, start_date, description, tier, validation_key, model_realms
#   Objects: , pending, highresmip2
#
# Subject: scen7-h-ext-pending.json
#   Predicates: model_realms, , validation_key, minimum_number_of_years, start_date, description, tier, parent_experiment, ui_label, activity
#   Objects: pending, , ismip7
#
# Subject: scen7-h-pending.json
#   Predicates: , start_date, activity, tier, model_realms, validation_key, minimum_number_of_years, ui_label, description, parent_experiment
#   Objects: , fast-track, pending
#
# Subject: scen7-hl-ext-pending.json
#   Predicates: ui_label, description, activity, , validation_key, parent_experiment, start_date, minimum_number_of_years, tier, model_realms
#   Objects: , ismip7, pending
#
# Subject: scen7-hl-pending.json
#   Predicates: parent_experiment, minimum_number_of_years, activity, , start_date, validation_key, description, model_realms, ui_label, tier
#   Objects: pending, , fast-track
#
# Subject: scen7-l-ext-pending.json
#   Predicates: parent_experiment, ui_label, , minimum_number_of_years, model_realms, validation_key, start_date, description, tier
#   Objects: pending,
#
# Subject: scen7-l-pending.json
#   Predicates: activity, start_date, description, tier, parent_experiment, minimum_number_of_years, ui_label, , validation_key, model_realms
#   Objects: fast-track, , pending
#
# Subject: scen7-ln-ext-pending.json
#   Predicates: description, tier, parent_experiment, ui_label, , start_date, minimum_number_of_years, model_realms, validation_key
#   Objects: , pending
#
# Subject: scen7-ln-pending.json
#   Predicates: ui_label, validation_key, minimum_number_of_years, description, tier, parent_experiment, activity, , start_date, model_realms
#   Objects: , pending, fast-track
#
# Subject: scen7-m-ext-pending.json
#   Predicates: , start_date, description, model_realms, activity, validation_key, minimum_number_of_years, ui_label, tier, parent_experiment
#   Objects: , pending, ismip7
#
# Subject: scen7-m-pending.json
#   Predicates: model_realms, , description, activity, start_date, validation_key, tier, parent_experiment, minimum_number_of_years, ui_label
#   Objects: pending, , fast-track
#
# Subject: scen7-ml-ext-pending.json
#   Predicates: minimum_number_of_years, start_date, ui_label, description, tier, parent_experiment, activity, , validation_key, model_realms
#   Objects: , pending, ismip7
#
# Subject: scen7-ml-pending.json
#   Predicates: parent_experiment, activity, start_date, validation_key, description, tier, minimum_number_of_years, ui_label, , model_realms
#   Objects: pending, fast-track,
#
# Subject: scen7-vl-ext-pending.json
#   Predicates: parent_experiment, validation_key, start_date, description, tier, ui_label, activity, , minimum_number_of_years, model_realms
#   Objects: pending, , ismip7
#
# Subject: scen7-vl-pending.json
#   Predicates: minimum_number_of_years, ui_label, activity, description, tier, parent_experiment, , validation_key, start_date, model_realms
#   Objects: , fast-track, pending
#
# Subject: tipmip-provisional-esm-up2p0-gwl1p5-pending.json
#   Predicates: ui_label, description, tier, , start_date, activity, model_realms, parent_experiment, validation_key, minimum_number_of_years
#   Objects: , tipmip, pending
#
# Subject: tipmip-provisional-esm-up2p0-gwl2p0-50y-dn2p0-pending.json
#   Predicates: start_date, model_realms, , minimum_number_of_years, validation_key, activity, description, tier, parent_experiment, ui_label
#   Objects: , pending, tipmip
#
# Subject: tipmip-provisional-esm-up2p0-gwl2p0-pending.json
#   Predicates: , model_realms, parent_experiment, ui_label, validation_key, start_date, activity, minimum_number_of_years, description, tier
#   Objects: , pending, tipmip
#
# Subject: tipmip-provisional-esm-up2p0-gwl3p0-pending.json
#   Predicates: start_date, ui_label, description, tier, minimum_number_of_years, , validation_key, activity, model_realms, parent_experiment
#   Objects: , tipmip, pending
#
# Subject: tipmip-provisional-esm-up2p0-gwl4p0-50y-dn2p0-gwl2p0-pending.json
#   Predicates: model_realms, , ui_label, validation_key, parent_experiment, minimum_number_of_years, start_date, activity, description, tier
#   Objects: pending, , tipmip
#
# Subject: tipmip-provisional-esm-up2p0-gwl4p0-50y-dn2p0-pending.json
#   Predicates: model_realms, , parent_experiment, start_date, activity, description, tier, ui_label, minimum_number_of_years, validation_key
#   Objects: pending, , tipmip
#
# Subject: tipmip-provisional-esm-up2p0-gwl4p0-pending.json
#   Predicates: model_realms, , description, start_date, tier, parent_experiment, ui_label, activity, validation_key, minimum_number_of_years
#   Objects: pending, , tipmip
#
# Subject: tipmip-provisional-esm-up2p0-gwl5p0-pending.json
#   Predicates: , model_realms, ui_label, validation_key, parent_experiment, minimum_number_of_years, start_date, activity, description, tier
#   Objects: , pending, tipmip
#
# Subject: tipmip-provisional-esm-up2p0-pending.json
#   Predicates: model_realms, description, , minimum_number_of_years, validation_key, tier, parent_experiment, ui_label, start_date, activity
#   Objects: pending, , tipmip

# %% [markdown]
# ## Using pandas and the raw json file

# %%
import pandas as pd

# %%
json_data = get('cmip7:experiment/graph.json', depth=0)

# %%
df = pd.DataFrame(json_data['@graph']).set_index('@id').sort_values(by='@type').drop(columns=['@type','model_realms']).replace('pending', '').fillna('')

mask = df.index.astype(str).str.contains(r'-pending(?:\.json)?$')
df = df[mask].set_index('validation_key')

for col in ['required', 'optional']:
    df[f"{col}_model_realms"] = ""

df
# Out:
#                                                                     activity  \
# validation_key
# tipmip-provisional-esm-up2p0-gwl4p0                                   tipmip
# tipmip-provisional-esm-up2p0-gwl4p0-50y-dn2p0                         tipmip
# tipmip-provisional-esm-up2p0-gwl4p0-50y-dn2p0-g...                    tipmip
# tipmip-provisional-esm-up2p0-gwl3p0                                   tipmip
# tipmip-provisional-esm-up2p0-gwl2p0                                   tipmip
# tipmip-provisional-esm-up2p0-gwl2p0-50y-dn2p0                         tipmip
# tipmip-provisional-esm-up2p0-gwl1p5                                   tipmip
# scen7-vl                                                          fast-track
# scen7-vl-ext                                                          ismip7
# scen7-ml                                                          fast-track
# scen7-ml-ext                                                          ismip7
# scen7-m-ext                                                           ismip7
# scen7-ln                                                          fast-track
# scen7-ln-ext                                                              []
# scen7-l                                                           fast-track
# scen7-l-ext                                                               []
# scen7-hl                                                          fast-track
# scen7-hl-ext                                                          ismip7
# scen7-h                                                           fast-track
# scen7-h-ext                                                           ismip7
# scen7-m                                                           fast-track
# dcppB-forecast                                                          dcpp
# dcppA-hindcast                                                          dcpp
# dcppA-assim                                                             dcpp
# esm-s7h-noFireChange                                                 firemip
# amip-noirr                                                            irrmip
# amip-irr                                                              irrmip
# esm-scen7-h-Aer                                     [fast-track, aerchemmip]
# esm-scen7-h-AQ                                      [fast-track, aerchemmip]
# esm-scen7-h-ext                                                       ismip7
# highres-future-scen7-m                                           highresmip2
# esm-scen7-vl                                                      fast-track
# esm-scen7-vl-ext                                                      ismip7
# esm-scen7-vl-AQ                                     [fast-track, aerchemmip]
# esm-scen7-vl-Aer                                    [fast-track, aerchemmip]
# esm-scen7-ml                                                      fast-track
# esm-scen7-ml-ext                                                      ismip7
# esm-scen7-m                                                       fast-track
# esm-scen7-m-ext                                                       ismip7
# esm-scen7-ln                                                      fast-track
# esm-scen7-ln-ext                                                          []
# esm-scen7-l                                                       fast-track
# esm-scen7-l-ext                                                           []
# esm-scen7-hl                                                      fast-track
# esm-scen7-hl-ext                                                      ismip7
# esm-scen7-h                                                       fast-track
# tipmip-provisional-esm-up2p0-gwl5p0                                   tipmip
# tipmip-provisional-esm-up2p0                                          tipmip
#
#                                                    alias description  \
# validation_key
# tipmip-provisional-esm-up2p0-gwl4p0                   []
# tipmip-provisional-esm-up2p0-gwl4p0-50y-dn2p0         []
# tipmip-provisional-esm-up2p0-gwl4p0-50y-dn2p0-g...    []
# tipmip-provisional-esm-up2p0-gwl3p0                   []
# tipmip-provisional-esm-up2p0-gwl2p0                   []
# tipmip-provisional-esm-up2p0-gwl2p0-50y-dn2p0         []
# tipmip-provisional-esm-up2p0-gwl1p5                   []
# scen7-vl                                              []
# scen7-vl-ext                                          []
# scen7-ml                                              []
# scen7-ml-ext                                          []
# scen7-m-ext                                           []
# scen7-ln                                              []
# scen7-ln-ext                                          []
# scen7-l                                               []
# scen7-l-ext                                           []
# scen7-hl                                              []
# scen7-hl-ext                                          []
# scen7-h                                               []
# scen7-h-ext                                           []
# scen7-m                                               []
# dcppB-forecast                                        []
# dcppA-hindcast                                        []
# dcppA-assim                                           []
# esm-s7h-noFireChange                                  []
# amip-noirr                                            []
# amip-irr                                              []
# esm-scen7-h-Aer                                       []
# esm-scen7-h-AQ                                        []
# esm-scen7-h-ext                                       []
# highres-future-scen7-m                                []
# esm-scen7-vl                                          []
# esm-scen7-vl-ext                                      []
# esm-scen7-vl-AQ                                       []
# esm-scen7-vl-Aer                                      []
# esm-scen7-ml                                          []
# esm-scen7-ml-ext                                      []
# esm-scen7-m                                           []
# esm-scen7-m-ext                                       []
# esm-scen7-ln                                          []
# esm-scen7-ln-ext                                      []
# esm-scen7-l                                           []
# esm-scen7-l-ext                                       []
# esm-scen7-hl                                          []
# esm-scen7-hl-ext                                      []
# esm-scen7-h                                           []
# tipmip-provisional-esm-up2p0-gwl5p0                   []
# tipmip-provisional-esm-up2p0                          []
#
#                                                    minimum_number_of_years  \
# validation_key
# tipmip-provisional-esm-up2p0-gwl4p0                                    300
# tipmip-provisional-esm-up2p0-gwl4p0-50y-dn2p0                          200
# tipmip-provisional-esm-up2p0-gwl4p0-50y-dn2p0-g...                     300
# tipmip-provisional-esm-up2p0-gwl3p0                                    300
# tipmip-provisional-esm-up2p0-gwl2p0                                    300
# tipmip-provisional-esm-up2p0-gwl2p0-50y-dn2p0                          100
# tipmip-provisional-esm-up2p0-gwl1p5                                    300
# scen7-vl                                                                75
# scen7-vl-ext                                                            50
# scen7-ml                                                                75
# scen7-ml-ext                                                            50
# scen7-m-ext                                                             50
# scen7-ln                                                                75
# scen7-ln-ext                                                            50
# scen7-l                                                                 75
# scen7-l-ext                                                             50
# scen7-hl                                                                75
# scen7-hl-ext                                                            50
# scen7-h                                                                 75
# scen7-h-ext                                                             50
# scen7-m                                                                 75
# dcppB-forecast                                                           5
# dcppA-hindcast                                                           5
# dcppA-assim                                                             56
# esm-s7h-noFireChange                                                    10
# amip-noirr                                                             122
# amip-irr                                                               122
# esm-scen7-h-Aer                                                        104
# esm-scen7-h-AQ                                                         104
# esm-scen7-h-ext                                                         50
# highres-future-scen7-m                                                  78
# esm-scen7-vl                                                            75
# esm-scen7-vl-ext                                                        50
# esm-scen7-vl-AQ                                                        104
# esm-scen7-vl-Aer                                                       104
# esm-scen7-ml                                                            75
# esm-scen7-ml-ext                                                        50
# esm-scen7-m                                                             75
# esm-scen7-m-ext                                                         50
# esm-scen7-ln                                                            75
# esm-scen7-ln-ext                                                        50
# esm-scen7-l                                                             75
# esm-scen7-l-ext                                                         50
# esm-scen7-hl                                                            75
# esm-scen7-hl-ext                                                        50
# esm-scen7-h                                                             75
# tipmip-provisional-esm-up2p0-gwl5p0                                    300
# tipmip-provisional-esm-up2p0                                           200
#
#                                                    parent_experiment  \
# validation_key
# tipmip-provisional-esm-up2p0-gwl4p0
# tipmip-provisional-esm-up2p0-gwl4p0-50y-dn2p0
# tipmip-provisional-esm-up2p0-gwl4p0-50y-dn2p0-g...
# tipmip-provisional-esm-up2p0-gwl3p0
# tipmip-provisional-esm-up2p0-gwl2p0
# tipmip-provisional-esm-up2p0-gwl2p0-50y-dn2p0
# tipmip-provisional-esm-up2p0-gwl1p5
# scen7-vl
# scen7-vl-ext
# scen7-ml
# scen7-ml-ext
# scen7-m-ext
# scen7-ln
# scen7-ln-ext
# scen7-l
# scen7-l-ext
# scen7-hl
# scen7-hl-ext
# scen7-h
# scen7-h-ext
# scen7-m
# dcppB-forecast
# dcppA-hindcast
# dcppA-assim
# esm-s7h-noFireChange
# amip-noirr
# amip-irr
# esm-scen7-h-Aer
# esm-scen7-h-AQ
# esm-scen7-h-ext
# highres-future-scen7-m
# esm-scen7-vl
# esm-scen7-vl-ext
# esm-scen7-vl-AQ
# esm-scen7-vl-Aer
# esm-scen7-ml
# esm-scen7-ml-ext
# esm-scen7-m
# esm-scen7-m-ext
# esm-scen7-ln
# esm-scen7-ln-ext
# esm-scen7-l
# esm-scen7-l-ext
# esm-scen7-hl
# esm-scen7-hl-ext
# esm-scen7-h
# tipmip-provisional-esm-up2p0-gwl5p0
# tipmip-provisional-esm-up2p0
#
#                                                    start_date tier ui_label  \
# validation_key
# tipmip-provisional-esm-up2p0-gwl4p0
# tipmip-provisional-esm-up2p0-gwl4p0-50y-dn2p0
# tipmip-provisional-esm-up2p0-gwl4p0-50y-dn2p0-g...
# tipmip-provisional-esm-up2p0-gwl3p0
# tipmip-provisional-esm-up2p0-gwl2p0
# tipmip-provisional-esm-up2p0-gwl2p0-50y-dn2p0
# tipmip-provisional-esm-up2p0-gwl1p5
# scen7-vl
# scen7-vl-ext
# scen7-ml
# scen7-ml-ext
# scen7-m-ext
# scen7-ln
# scen7-ln-ext
# scen7-l
# scen7-l-ext
# scen7-hl
# scen7-hl-ext
# scen7-h
# scen7-h-ext
# scen7-m
# dcppB-forecast
# dcppA-hindcast
# dcppA-assim
# esm-s7h-noFireChange
# amip-noirr
# amip-irr
# esm-scen7-h-Aer
# esm-scen7-h-AQ
# esm-scen7-h-ext
# highres-future-scen7-m
# esm-scen7-vl
# esm-scen7-vl-ext
# esm-scen7-vl-AQ
# esm-scen7-vl-Aer
# esm-scen7-ml
# esm-scen7-ml-ext
# esm-scen7-m
# esm-scen7-m-ext
# esm-scen7-ln
# esm-scen7-ln-ext
# esm-scen7-l
# esm-scen7-l-ext
# esm-scen7-hl
# esm-scen7-hl-ext
# esm-scen7-h
# tipmip-provisional-esm-up2p0-gwl5p0
# tipmip-provisional-esm-up2p0
#
#                                                    end min_number_yrs_per_sim  \
# validation_key
# tipmip-provisional-esm-up2p0-gwl4p0
# tipmip-provisional-esm-up2p0-gwl4p0-50y-dn2p0
# tipmip-provisional-esm-up2p0-gwl4p0-50y-dn2p0-g...
# tipmip-provisional-esm-up2p0-gwl3p0
# tipmip-provisional-esm-up2p0-gwl2p0
# tipmip-provisional-esm-up2p0-gwl2p0-50y-dn2p0
# tipmip-provisional-esm-up2p0-gwl1p5
# scen7-vl
# scen7-vl-ext
# scen7-ml
# scen7-ml-ext
# scen7-m-ext
# scen7-ln
# scen7-ln-ext
# scen7-l
# scen7-l-ext
# scen7-hl
# scen7-hl-ext
# scen7-h
# scen7-h-ext
# scen7-m
# dcppB-forecast
# dcppA-hindcast
# dcppA-assim
# esm-s7h-noFireChange
# amip-noirr
# amip-irr
# esm-scen7-h-Aer
# esm-scen7-h-AQ
# esm-scen7-h-ext
# highres-future-scen7-m
# esm-scen7-vl
# esm-scen7-vl-ext
# esm-scen7-vl-AQ
# esm-scen7-vl-Aer
# esm-scen7-ml
# esm-scen7-ml-ext
# esm-scen7-m
# esm-scen7-m-ext
# esm-scen7-ln
# esm-scen7-ln-ext
# esm-scen7-l
# esm-scen7-l-ext
# esm-scen7-hl
# esm-scen7-hl-ext
# esm-scen7-h
# tipmip-provisional-esm-up2p0-gwl5p0
# tipmip-provisional-esm-up2p0
#
#                                                    start branch_date  \
# validation_key
# tipmip-provisional-esm-up2p0-gwl4p0
# tipmip-provisional-esm-up2p0-gwl4p0-50y-dn2p0
# tipmip-provisional-esm-up2p0-gwl4p0-50y-dn2p0-g...
# tipmip-provisional-esm-up2p0-gwl3p0
# tipmip-provisional-esm-up2p0-gwl2p0
# tipmip-provisional-esm-up2p0-gwl2p0-50y-dn2p0
# tipmip-provisional-esm-up2p0-gwl1p5
# scen7-vl
# scen7-vl-ext
# scen7-ml
# scen7-ml-ext
# scen7-m-ext
# scen7-ln
# scen7-ln-ext
# scen7-l
# scen7-l-ext
# scen7-hl
# scen7-hl-ext
# scen7-h
# scen7-h-ext
# scen7-m
# dcppB-forecast
# dcppA-hindcast
# dcppA-assim
# esm-s7h-noFireChange
# amip-noirr
# amip-irr
# esm-scen7-h-Aer
# esm-scen7-h-AQ
# esm-scen7-h-ext
# highres-future-scen7-m
# esm-scen7-vl
# esm-scen7-vl-ext
# esm-scen7-vl-AQ
# esm-scen7-vl-Aer
# esm-scen7-ml
# esm-scen7-ml-ext
# esm-scen7-m
# esm-scen7-m-ext
# esm-scen7-ln
# esm-scen7-ln-ext
# esm-scen7-l
# esm-scen7-l-ext
# esm-scen7-hl
# esm-scen7-hl-ext
# esm-scen7-h
# tipmip-provisional-esm-up2p0-gwl5p0
# tipmip-provisional-esm-up2p0
#
#                                                    required_model_realms  \
# validation_key
# tipmip-provisional-esm-up2p0-gwl4p0
# tipmip-provisional-esm-up2p0-gwl4p0-50y-dn2p0
# tipmip-provisional-esm-up2p0-gwl4p0-50y-dn2p0-g...
# tipmip-provisional-esm-up2p0-gwl3p0
# tipmip-provisional-esm-up2p0-gwl2p0
# tipmip-provisional-esm-up2p0-gwl2p0-50y-dn2p0
# tipmip-provisional-esm-up2p0-gwl1p5
# scen7-vl
# scen7-vl-ext
# scen7-ml
# scen7-ml-ext
# scen7-m-ext
# scen7-ln
# scen7-ln-ext
# scen7-l
# scen7-l-ext
# scen7-hl
# scen7-hl-ext
# scen7-h
# scen7-h-ext
# scen7-m
# dcppB-forecast
# dcppA-hindcast
# dcppA-assim
# esm-s7h-noFireChange
# amip-noirr
# amip-irr
# esm-scen7-h-Aer
# esm-scen7-h-AQ
# esm-scen7-h-ext
# highres-future-scen7-m
# esm-scen7-vl
# esm-scen7-vl-ext
# esm-scen7-vl-AQ
# esm-scen7-vl-Aer
# esm-scen7-ml
# esm-scen7-ml-ext
# esm-scen7-m
# esm-scen7-m-ext
# esm-scen7-ln
# esm-scen7-ln-ext
# esm-scen7-l
# esm-scen7-l-ext
# esm-scen7-hl
# esm-scen7-hl-ext
# esm-scen7-h
# tipmip-provisional-esm-up2p0-gwl5p0
# tipmip-provisional-esm-up2p0
#
#                                                    optional_model_realms
# validation_key
# tipmip-provisional-esm-up2p0-gwl4p0
# tipmip-provisional-esm-up2p0-gwl4p0-50y-dn2p0
# tipmip-provisional-esm-up2p0-gwl4p0-50y-dn2p0-g...
# tipmip-provisional-esm-up2p0-gwl3p0
# tipmip-provisional-esm-up2p0-gwl2p0
# tipmip-provisional-esm-up2p0-gwl2p0-50y-dn2p0
# tipmip-provisional-esm-up2p0-gwl1p5
# scen7-vl
# scen7-vl-ext
# scen7-ml
# scen7-ml-ext
# scen7-m-ext
# scen7-ln
# scen7-ln-ext
# scen7-l
# scen7-l-ext
# scen7-hl
# scen7-hl-ext
# scen7-h
# scen7-h-ext
# scen7-m
# dcppB-forecast
# dcppA-hindcast
# dcppA-assim
# esm-s7h-noFireChange
# amip-noirr
# amip-irr
# esm-scen7-h-Aer
# esm-scen7-h-AQ
# esm-scen7-h-ext
# highres-future-scen7-m
# esm-scen7-vl
# esm-scen7-vl-ext
# esm-scen7-vl-AQ
# esm-scen7-vl-Aer
# esm-scen7-ml
# esm-scen7-ml-ext
# esm-scen7-m
# esm-scen7-m-ext
# esm-scen7-ln
# esm-scen7-ln-ext
# esm-scen7-l
# esm-scen7-l-ext
# esm-scen7-hl
# esm-scen7-hl-ext
# esm-scen7-h
# tipmip-provisional-esm-up2p0-gwl5p0
# tipmip-provisional-esm-up2p0

# %% [markdown]
# #### We now want to write the data to a spreadsheet. We can use openpyxl for this purpose.

# %%
df_scen7 = df[df.index.str.contains('scen7')]
df_tipmip = df[df.index.str.contains('tipmip')]
df_neither = df[~(df.index.str.contains('scen7') | df.index.str.contains('tipmip'))]

# %%
with pd.ExcelWriter('pending-experiments.xlsx', mode='w', engine='openpyxl') as writer:
    
    df_scen7.to_excel(writer, sheet_name='scen7')
    df_tipmip.to_excel(writer, sheet_name='tipmip')
    df_neither.to_excel(writer, sheet_name='other')
