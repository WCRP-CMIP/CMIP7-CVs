# %%
import re,json,glob,cmipld

# %%
files = glob.glob('*.json')

# %%
for f in files:
    with open(f) as fp:
        jd = json.load(fp)
        
    print(jd['model_realms'])
    
    
    # jd['model_realms_required'] = sorted([r.get('@id',r) for r in jd.get('model_realms',[]) if r.get('is_required')])
    
    # jd['model_realms_additional_allowed'] = sorted([r.get('@id',r) for r in jd.get('model_realms',[]) if not r.get('is_required')])
    
    # del jd['model_realms']
    
    
    
    
    
    # doi = cmipld.utils.texttools.get_doi(str(jd))
    
    # jd['references'] = doi
    
    # with open(f, 'w') as fp:
    #     json.dump(jd, fp, indent=2)
# Out:
# []
# [{'@id': 'agcm', 'is_required': True}, {'@id': 'aer', 'is_required': False}, {'@id': 'bgc', 'is_required': False}, {'@id': 'chem', 'is_required': False}]
# [{'@id': 'agcm', 'is_required': True}, {'@id': 'aer', 'is_required': False}, {'@id': 'bgc', 'is_required': False}, {'@id': 'chem', 'is_required': False}]
# [{'@id': 'agcm', 'is_required': True}, {'@id': 'aer', 'is_required': False}, {'@id': 'bgc', 'is_required': False}, {'@id': 'chem', 'is_required': False}]
# [{'@id': 'aogcm', 'is_required': True}]
# [{'@id': 'aogcm', 'is_required': True}, {'@id': 'bgc', 'is_required': True}, {'@id': 'aer', 'is_required': False}, {'@id': 'chem', 'is_required': False}]
# [{'@id': 'pending', 'is_required': True}]
# [{'@id': 'agcm', 'is_required': True}, {'@id': 'aer', 'is_required': False}, {'@id': 'bgc', 'is_required': False}, {'@id': 'chem', 'is_required': False}]
# [{'@id': 'agcm', 'is_required': True}, {'@id': 'chem', 'is_required': True}]
# ...
